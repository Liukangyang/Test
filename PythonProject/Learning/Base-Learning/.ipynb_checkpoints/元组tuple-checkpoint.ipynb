# %%
#元组定义
tuple1=(1,2,'LKY')
tuple1
# Out:
# (1, 2, 'LKY')

# %%
tup1=(50)
type(tup1)
# Out:
# int

# %%
tup2=(50,)
type(tup2)
# Out:
# tuple

# %%
tup3 = (1, 2, 3, 4, 5, 6, 7 )
print(tup3[1:-1])
# Out:
# (2, 3, 4, 5, 6)

# %%
tup3[0]=100  #元组不允许修改元素
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_68764/2290516726.py in <module>
# ----> 1 tup3[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
tup4=tup3+tup2  #元组可以拼接组合
tup4
# Out:
# (1, 2, 3, 4, 5, 6, 7, 50)

# %%
del tup4[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_68764/2679305850.py in <module>
# ----> 1 del tup4[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %% [markdown]
# del tup4
# tup4

# %%
tup5=('Hi','!')
tup5*=4
tup5
# Out:
# ('Hi', '!', 'Hi', '!', 'Hi', '!', 'Hi', '!')

# %%
for x in (1, 2, 3): 
    print (x, end=",")
# Out:
# 1,2,3,

# %% [markdown]
# #内置函数

# %%
#1.len()
len(tup5)
# Out:
# 8

# %%
#2.max()相同类型
max((5,10))
# Out:
# 10

# %%
#3.min()
min((5,10))
# Out:
# 5

# %%
#4.tuple()
list1=[1,2,3,4]
list1[0]=20
list1
# Out:
# [20, 2, 3, 4]

# %%
type(list1)
# Out:
# list

# %%
tup6=tuple(list1);
type(tup6)
# Out:
# tuple

# %%
tup6[0]=2  #转化为元组类型后补课更改
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_68764/4092571992.py in <module>
# ----> 1 tup6[0]=2
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# 关于元组是不可变的
# 所谓元组的不可变指的是元组所指向的内存中的内容不可变。
