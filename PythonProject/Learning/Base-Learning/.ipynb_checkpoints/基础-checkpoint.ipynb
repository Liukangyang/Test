# %%
a=b=c=1

# %%
print(a,b,c)
# Out:
# 1 1 1

# %%
type(a)
# Out:
# int

# %%
isinstance(a,int)
# Out:
# True

# %%
isinstance(a,float)
# Out:
# False

# %%
True+2
# Out:
# 3

# %%
False-1
# Out:
# -1

# %%
2**3
# Out:
# 8

# %%
3/2  #返回浮点数
# Out:
# 1.5

# %%
3//2 #返回整数
# Out:
# 1

# %%
complex(2,-1)+complex(2,1)
# Out:
# (4+0j)

# %% [markdown]
# #数据类型转换

# %%
#隐式类型转换 - 自动完成
#显式类型转换 - 需要使用类型函数来转换

# %%
#整形与浮点型运算
num_int=123
num_flo=1.23

# %%
num_new=num_int+num_flo

# %%
num_new
# Out:
# 124.23

# %%
type(num_new)
# Out:
# float

# %%
#整形与字符型运算
num_int=123;
num_str='456';

# %%
num_int+num_str
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10796/1085959440.py in <module>
# ----> 1 num_int+num_str
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#显式类型转化
int(2.99)
# Out:
# 2

# %%
float('3')
# Out:
# 3.0

# %%
str(3.29)
# Out:
# '3.29'

# %%
num_int+int(num_str)
# Out:
# 579

# %%
eval('a+b')
# Out:
# 2

# %%
chr(22)
# Out:
# '\x16'

# %%
ord('\x11')
# Out:
# 17

# %%
hex(100)  #将一个整数转换为一个十六进制字符串
# Out:
# '0x64'

# %%
oct(100)  #将一个整数转换为一个八进制字符串
# Out:
# '0o144'
