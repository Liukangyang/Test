# %% [markdown]
# #列表

# %%
list1=[1,2,3,4,5];
list1
# Out:
# [1, 2, 3, 4, 5]

# %%
list2=['L','LKY',22,100.23];
list2
# Out:
# ['L', 'LKY', 22, 100.23]

# %%
#索引
print(list2[0]);
print(list2[1]);
# Out:
# L
# LKY

# %%
print(list2[3])
print(list2[-1])
print(list2[-3])
# Out:
# 100.23
# 100.23
# LKY

# %%
#索引截取
print(list1[0:3])
# Out:
# [1, 2, 3]

# %%
print(list1[1:-2])
# Out:
# [2, 3]

# %% [markdown]
# #列表操作

# %%
#1.删除元素
del list1[1]
list1
# Out:
# [1, 3, 4, 5]

# %%
#2.添加元素append
list1.append(6);
list1
# Out:
# [3, 6, 6, 6]

# %%
#3.移动元素pop
print(list1.pop(2))
list1
# Out:
# 6
# [3, 6]

# %%
#remove
list1.remove(1)
list1
# Out:
# [3, 6]

# %%
#4.count
print(list1.count(3))
print(list1.count(6))
# Out:
# 1
# 3

# %%
#5.index
print(list1.index(3))
print(list1.index(6))
# Out:
# 0
# 1

# %%
#6.insert
list1.insert(2,10)
list1
# Out:
# [3, 6, 10, 6, 6, 10, -1]

# %%
#7.sort
list1.sort(reverse=True)
list1
# Out:
# [10, 10, 6, 6, 6, 3, -1]

# %%
#8.reverse
print(list2)
list2.reverse();
print(list2)
# Out:
# ['L', 'LKY', 22, 100.23]
# [100.23, 22, 'LKY', 'L']

# %%
#9.copy
list6=list2.copy();
print(list6);
print(id(list6)==id(list2))
# Out:
# [100.23, 22, 'LKY', 'L']
# False

# %%
#10.clear
print(list6);
list6.clear();
print(list6);
# Out:
# [100.23, 22, 'LKY', 'L']
# []

# %%
#4.操作符号
list3=[6,7,8]
list_new=list1+list3
print(list_new)
print(len(list_new))
# Out:
# [1, 3, 4, 5, 6, 7, 8]
# 7

# %%
list3*3
# Out:
# [6, 7, 8, 6, 7, 8, 6, 7, 8]

# %%
list_new[2:]
# Out:
# [4, 5, 6, 7, 8]

# %%
list_new+=['hello','world','!'];
list_new
# Out:
# [1, 3, 4, 5, 6, 7, 8, 'hello', 'world', '!']

# %%
#列表嵌套
list4=[list1,list2];
list4
# Out:
# [[1, 3, 4, 5], ['L', 'LKY', 22, 100.23]]

# %%
list4[0]
# Out:
# [1, 3, 4, 5]

# %%
list4[0][2]
# Out:
# 4

# %%
#列表比较
lista=[1,2,3];
listb=[4,5,6];
listc=[3,2,1];

# %%
import operator
operator.eq(lista,listb)
# Out:
# False

# %%
operator.eq(lista,listc)
# Out:
# False

# %%
#python内置函数
print(len(list1));
print(max(list1));
print(min(list1));
# Out:
# 4
# 5
# 1
